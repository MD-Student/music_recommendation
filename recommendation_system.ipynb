# %% [markdown]
# # 推荐系统实现

# %% [markdown]
# ## 根据用户数据提取歌曲特征

# %%
import pandas as pd
import seaborn as sns
import scipy.sparse as sp
from sklearn import ensemble
from sklearn.decomposition import TruncatedSVD
from matplotlib import pyplot as plt
import matplotlib
ZHFONT = matplotlib.font_manager.FontProperties(fname="data/SourceHanSansSC-Regular.otf")

df_train = pd.read_csv("data/train.csv")
df_songs = pd.read_csv("data/songs.csv")
df_songs_extra = pd.read_csv("data/song_extra_info.csv")

# 将train，songs和songs_extra进行内连接
df_train = df_train.merge(df_songs,on="song_id",how="inner")
df_train = df_train.merge(df_songs_extra,on="song_id",how="inner")

# %%
# 将文本类别转换成 Category以计算相关性
for col in df_train.select_dtypes(include=['object']).columns:
    df_train[col] = df_train[col].astype('category')
    df_train[col] = df_train[col].cat.codes
corr = df_train.corr()

# %%
# 创建稀疏矩阵
df_train_grouped = df_train.groupby(['msno','song_id'])
df_train_grouped = df_train_grouped.size().reset_index(name='play_count')

user_song_sparse_matrix = sp.coo_matrix((df_train_grouped['play_count'], (df_train_grouped['msno'].astype('category').cat.codes, df_train_grouped['song_id'].astype('category').cat.codes)))

# %%
# 计算每首歌曲的SVD向量表示
K = 64
svd = TruncatedSVD(n_components=K)
song_user_sparse_matrix = sp.coo_matrix((df_train_grouped['play_count'], (df_train_grouped['song_id'].astype('category').cat.codes, df_train_grouped['msno'].astype('category').cat.codes)))

# SVD算法
song_user_svd = svd.fit_transform(song_user_sparse_matrix)
song_user_features = pd.DataFrame(song_user_svd, 
                                columns=[f'特征{i+1}' for i in range(K)],
                                index=df_train_grouped['song_id'].astype('category').cat.categories)

# %%
# 拼接歌曲名称等信息
song_user_features['song_id'] = pd.Series(range(song_user_features.shape[0]))

# 重新读取未经编码的数据
df_train = pd.read_csv("data/train.csv")
df_songs = pd.read_csv("data/songs.csv")
df_songs_extra = pd.read_csv("data/song_extra_info.csv")
df_train = df_train.merge(df_songs,on="song_id",how="inner")
df_train = df_train.merge(df_songs_extra,on="song_id",how="inner")
# 只编码song_id，保证一致
df_train['song_id'] = df_train['song_id'].astype('category').cat.codes
df_train = df_train.drop_duplicates(subset=['song_id'],keep='first')
df_train = df_train.merge(song_user_features,how='inner',on='song_id')
display(df_train.shape)
display(df_train.head(15))
# Out:
# (359755, 78)
#                                             msno  song_id source_system_tab  \
# 0   FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=    74631           explore
# 1   Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=   223347        my library
# 2   Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=   120686        my library
# 3   Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=    23688        my library
# 4   FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=    33284           explore
# 5   FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=    30167           explore
# 6   Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=   189910        my library
# 7   FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=   221696           explore
# 8   uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=     9173        my library
# 9   uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=    93766        my library
# 10  uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=   320763        my library
# 11  uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=    58069        my library
# 12  TJU0Gfvy7FB+r89bWovPKXTjuApTCiv3xg/tt5shR78=   326924        my library
# 13  3g0bC24RD7QUeALY1IF/e8L6X3fHG298ZFIsCEG9T9Y=   177564        my library
# 14  TJU0Gfvy7FB+r89bWovPKXTjuApTCiv3xg/tt5shR78=   116704        my library
#
#      source_screen_name          source_type  target  song_length genre_ids  \
# 0               Explore      online-playlist       1       206471       359
# 1   Local playlist more       local-playlist       1       284584      1259
# 2   Local playlist more       local-playlist       1       225396      1259
# 3   Local playlist more       local-playlist       1       255512      1019
# 4               Explore      online-playlist       1       187802      1011
# 5               Explore      online-playlist       1       247803      1259
# 6   Local playlist more       local-playlist       1       229982       465
# 7               Explore      online-playlist       1       181115      1011
# 8   Local playlist more        local-library       1       278964      2022
# 9   Local playlist more        local-library       1       257369       465
# 10  Local playlist more        local-library       1       223933       465
# 11  Local playlist more        local-library       1       224597       465
# 12                  NaN  top-hits-for-artist       0       280084       465
# 13  Local playlist more        local-library       1       253492       458
# 14  Local playlist more       local-playlist       1       210364   465|458
#
#          artist_name                                 composer  ...      特征55  \
# 0           Bastille                     Dan Smith| Mark Crew  ... -0.669902
# 1    Various Artists                                      NaN  ...  0.011652
# 2                Nas     N. Jones、W. Adams、J. Lordan、D. Ingle  ...  0.004484
# 3           Soundway                            Kwadwo Donkoh  ...  0.011652
# 4        Brett Young  Brett Young| Kelly Archer| Justin Ebach  ... -1.488168
# 5          Desiigner                 Sidney Selby| Adnan Khan  ...  0.179260
# 6    BIGBANG TAEYANG            TEDDY| DEE.P| Rebecca Johnson  ... -1.695626
# 7       Thomas Rhett   Thomas Rhett| Rhett Akins| Ben Hayslip  ... -0.881164
# 8        OneRepublic                              Ryan Tedder  ...  0.084390
# 9        OneRepublic                              Ryan Tedder  ...  0.116966
# 10  Lindsey Stirling    Lindsey Stirling| Dia Frampton| SILAS  ...  0.018604
# 11        嚴爵 (Yen-j)                                       嚴爵  ...  0.045498
# 12      林俊傑 (JJ Lin)                                      林俊傑  ... -0.138259
# 13    周杰倫 (Jay Chou)                                      周杰倫  ... -2.752389
# 14      林俊傑 (JJ Lin)                                   JJ Lin  ... -0.359743
#
#         特征56      特征57      特征58      特征59      特征60      特征61      特征62  \
# 0  -0.814714  0.365887  0.625832 -0.414132  0.449320  0.094190 -0.198572
# 1   0.003097  0.003180 -0.008135 -0.003253 -0.005914 -0.008940 -0.003045
# 2  -0.041385  0.011043  0.038386  0.028808  0.080269  0.023810 -0.040498
# 3   0.003097  0.003180 -0.008135 -0.003253 -0.005914 -0.008940 -0.003045
# 4  -1.639779  0.392439 -0.101235 -1.530603 -0.733189  0.995997  1.201326
# 5  -0.061225 -0.984969 -0.833324  1.912671  1.751444 -1.647275 -0.325898
# 6   2.074209 -1.928169  1.301798 -0.168560 -0.928602  0.619620 -1.626899
# 7  -1.281910  0.488264 -0.140746 -1.270513 -0.497853  0.805853  0.915915
# 8  -0.061995  0.063706  0.125521  0.016351  0.019265 -0.004544 -0.111708
# 9   0.299618 -0.085313  0.349382 -1.017769  0.148962 -0.386848  1.921020
# 10 -0.017556  0.008332  0.002831 -0.000739  0.017012 -0.017531 -0.001991
# 11 -0.837263 -0.724027 -0.471066 -0.747993  0.097226 -0.059129  0.314495
# 12 -1.029645  2.250884  1.466172  0.088254  0.893221  1.043854  1.721537
# 13 -1.094040  3.560038 -2.916467  4.571066 -2.103715  1.330434 -3.190201
# 14  0.855385  0.396391  0.848224  0.992473 -0.492213  3.211751 -1.888377
#
#         特征63      特征64
# 0   0.458480  0.207223
# 1  -0.008815  0.000713
# 2   0.036063  0.043778
# 3  -0.008815  0.000713
# 4   1.178950 -0.927256
# 5   0.598098  0.804848
# 6  -1.952161  0.658397
# 7   1.048601 -0.717854
# 8  -0.098042 -0.018869
# 9  -0.766945 -0.314502
# 10 -0.013292  0.000333
# 11 -0.029684  0.262232
# 12 -0.735036 -1.704976
# 13  3.036527  1.426327
# 14 -1.527182 -0.217943
#
# [15 rows x 78 columns]

# %%
# 只保留中文歌曲，language=3
df_train.drop(['msno','source_system_tab','source_screen_name','source_type'],axis=1,inplace= True)
df_train = df_train.loc[df_train['language'] == 3]
display(df_train.head(15))
# Out:
#     song_id  target  song_length genre_ids        artist_name     composer  \
# 11    58069       1       224597       465         嚴爵 (Yen-j)           嚴爵
# 12   326924       0       280084       465       林俊傑 (JJ Lin)          林俊傑
# 13   177564       1       253492       458     周杰倫 (Jay Chou)          周杰倫
# 14   116704       1       210364   465|458       林俊傑 (JJ Lin)       JJ Lin
# 16   214152       1       248790       465      吳汶芳 (Fang Wu)          吳汶芳
# 17   321525       1       259877       458         aMEI (張惠妹)    Wang Feng
# 18    37437       0       265743       465       林俊傑 (JJ Lin)       JJ Lin
# 19    67806       1       241975       465    孫燕姿 (Yanzi Sun)  Li Wei Song
# 20   190425       1       189846       458   陳星翰 (Starr Chen)   Starr Chen
# 21   107310       1       247911       465    莫文蔚 (Karen Mok)  Skot Suyama
# 22   280430       1       257671       465       五月天 (Mayday)          NaN
# 28   264800       1       271255       465              S.H.E          周杰倫
# 29    81042       1       248581       NaN  韋禮安 (William Wei)          韋禮安
# 30   175866       1       183484       465              S.H.E          NaN
# 31     6097       1       260806       465              S.H.E           鄭楠
#
#        lyricist  language                               name          isrc  \
# 11           嚴爵       3.0                       輕輕 (Lightly)  TWK231507907
# 12          林怡鳳       3.0  手心的薔薇 (Beautiful) feat. G.E.M.鄧紫棋  TWA531480006
# 13          周杰倫       3.0                           給我一首歌的時間  TWK970801502
# 14  Lin Yi Feng       3.0                      關鍵詞 (The Key)  TWA531576504
# 16          吳汶芳       3.0     孤獨的總和 (Accumulated Loneliness)  TWA211328806
# 17          NaN       3.0                                春天裡  TWUM71600101
# 18  Wang Ya Jun       3.0                    因你而在 (You N Me)  TWA531398014
# 19     Xiao Han       3.0                            雨天 (雨天)  TWA530617601
# 20          NaN       3.0           EGO-HOLIC戀我癖 (EGO-HOLIC)  TWUM71600076
# 21          李焯雄       3.0                                愛死你  TWA470326002
# 22          NaN       3.0                                麥來亂  TWA450586306
# 28    Selina+李姚       3.0                                安靜了  TWD950806109
# 29          韋禮安       3.0                              Intro  TWA211630901
# 30          藍小邪       3.0                               宇宙小姐  TWD950806103
# 31          黃建洲       3.0                            沿海公路的出口  TWD950806104
#
#     ...      特征55      特征56      特征57      特征58      特征59      特征60      特征61  \
# 11  ...  0.045498 -0.837263 -0.724027 -0.471066 -0.747993  0.097226 -0.059129
# 12  ... -0.138259 -1.029645  2.250884  1.466172  0.088254  0.893221  1.043854
# 13  ... -2.752389 -1.094040  3.560038 -2.916467  4.571066 -2.103715  1.330434
# 14  ... -0.359743  0.855385  0.396391  0.848224  0.992473 -0.492213  3.211751
# 16  ... -1.390997 -1.829017 -3.270219 -0.912881  0.859131  0.205735 -1.217894
# 17  ...  1.573981 -0.967788  0.269891 -1.185992  0.183924 -0.884661  0.255855
# 18  ... -0.134129 -1.060240 -1.272638  1.289265  0.766787  1.523809  1.033244
# 19  ... -1.211062  0.547520  0.082267  0.329495 -0.625898 -0.198381 -0.108539
# 20  ... -1.329635  0.403698  3.941835  0.461805 -3.731353  0.322436 -1.190308
# 21  ... -0.030639  0.516861  0.235568 -0.044960  0.388393  0.044496 -0.333293
# 22  ... -0.613792  0.194574  0.100659  0.141057 -0.438419 -0.239341  0.007575
# 28  ... -0.129499 -0.905622  0.800940 -0.565501  0.660646 -1.173043 -0.502466
# 29  ... -0.195895  0.560628  0.676569 -2.051721  1.129638  2.812487  0.142425
# 30  ... -0.120944 -0.247228  0.201583  0.079522  0.394972 -0.325910 -0.025732
# 31  ... -0.832329 -0.481511 -0.059514 -0.601807  1.030923 -0.446396 -0.206613
#
#         特征62      特征63      特征64
# 11  0.314495 -0.029684  0.262232
# 12  1.721537 -0.735036 -1.704976
# 13 -3.190201  3.036527  1.426327
# 14 -1.888377 -1.527182 -0.217943
# 16 -1.219546 -0.006928  0.226888
# 17 -0.112575  0.436283 -1.058460
# 18  0.800090  2.494180  0.902940
# 19 -0.802532  0.838897 -1.555693
# 20 -0.032522  0.149215  2.531194
# 21  0.364095  0.225322 -0.151769
# 22 -0.404542  0.224184  0.009121
# 28 -0.302371 -0.129156  0.525417
# 29  0.089075 -1.051159 -2.013955
# 30  0.292862 -0.431568  0.298512
# 31  0.035849 -0.039738  0.778249
#
# [15 rows x 74 columns]

# %%
# 保存到本地
df_train.drop(['target'],axis=1,inplace=True)
display(df_train.shape)
df_train.to_csv('data/songs_features.csv',index=False)
# Out:
# (60866, 73)
